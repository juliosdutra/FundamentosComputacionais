# %% [markdown]
# <a href="https://colab.research.google.com/github/juliosdutra/FundamentosComputacionais/blob/main/Verifica_Idade.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="data:image/png;base64,..." alt="ponto vermelho" width="500"/>

# %% [markdown]
# ---
# A programação foi feita conforme o fluxograma abaixo.

# %% [markdown]
# <img src="data:image/png;base64,..." alt="ponto vermelho" width="200"/>

# %%
idade = int(input("Digite a idade da pessoa: "))

if idade >= 18:
  print("A pessoa é maior de idade.")
else:
  print("A pessoa é menor de idade.")
# Out:
# Digite a idade da pessoa: 25
# A pessoa é maior de idade.
